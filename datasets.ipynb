# %%
import pandas as pd

# %%
url4 = 'https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv'

# %%
df = pd.read_csv(url4)

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df.sort_values("Rows")
# Out:
#            Package             Item  \
# 1671         tidyr           smiths
# 1556     Stat2Data              TMS
# 723            gap         jma.cojo
# 1395     Stat2Data         ChemoTHC
# 1307      reshape2           smiths
# ...            ...              ...
# 1641     stevedata        wvs_immig
# 1041  nycflights13          flights
# 1642     stevedata  wvs_justifbribe
# 1007    mosaicData        Birthdays
# 1157     openintro         military
#
#                                                   Title     Rows  Cols  \
# 1671                   Some data about the Smith family        2     5
# 1556                                  Migraines and TMS        2     4
# 723                          Internal functions for gap        2    16
# 1395       THC for Antinausea Treatment in Chemotherapy        2     4
# 1307                   Demo data describing the Smiths.        2     5
# ...                                                 ...      ...   ...
# ...

# %%
df.sort_values("Cols")
# Out:
#          Package                   Item  \
# 57           AER        MSCISwitzerland
# 129         boot                 darwin
# 1011  mosaicData                  Cards
# 128         boot                   coal
# 232   causaldata  gov_transfers_density
# ...          ...                    ...
# 718          gap                  crohn
# 383         DAAG                rockArt
# 1020  mosaicData               HELPfull
# 1258        plyr                  ozone
# 859         ISLR                  NCI60
#
#                                                   Title   Rows  Cols  \
# 57                               MSCI Switzerland Index   4697     1
# 129                   Darwin's Plant Height Differences     15     1
# 1011                             Standard Deck of Cards     52     1
# 128                      Dates of Coal Mining Disasters    191     1
# 232   Data from "Government Transfers and Political ...  52549     1
# ...

# %%
df['CSV']
# Out:
# 0       https://vincentarelbundock.github.io/Rdatasets...
# 1       https://vincentarelbundock.github.io/Rdatasets...
# 2       https://vincentarelbundock.github.io/Rdatasets...
# 3       https://vincentarelbundock.github.io/Rdatasets...
# 4       https://vincentarelbundock.github.io/Rdatasets...
#                               ...
# 1709    https://vincentarelbundock.github.io/Rdatasets...
# 1710    https://vincentarelbundock.github.io/Rdatasets...
# 1711    https://vincentarelbundock.github.io/Rdatasets...
# 1712    https://vincentarelbundock.github.io/Rdatasets...
# 1713    https://vincentarelbundock.github.io/Rdatasets...
# Name: CSV, Length: 1714, dtype: object

# %%
df1 = df[df['Rows']==387]

# %%
df1
# Out:
#     Package   Item                       Title  Rows  Cols  n_binary  \
# 718     gap  crohn  Internal functions for gap   387   212         2
#
#      n_character  n_factor  n_logical  n_numeric  \
# 718            0         1          0        211
#
#                                                    CSV  \
# 718  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                    Doc
# 718  https://vincentarelbundock.github.io/Rdatasets...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1['CSV'])
# Out:
# pandas.core.series.Series

# %%
csvname = df1['CSV']

# %%
csvname
# Out:
# 718    https://vincentarelbundock.github.io/Rdatasets...
# Name: CSV, dtype: object

# %%
pd.Series(csvname).values[0]
# Out:
# 'https://vincentarelbundock.github.io/Rdatasets/csv/gap/crohn.csv'

# %%
pd.read_csv(pd.Series(csvname).values[0])
# Out:
#      Unnamed: 0       pid    id   fid   mid  sex  crohn  loc1.a1  loc1.a2  \
# 0             1    PED054   430     0     0    1      0        1        3
# 1             2    PED054   412   430   431    2      2        1        3
# 2             3    PED054   431     0     0    2      0        3        3
# 3             4    PED058   438     0     0    1      0        3        3
# 4             5    PED058   470   438   444    2      2        3        3
# ..          ...       ...   ...   ...   ...  ...    ...      ...      ...
# 382         383  PEDX8413  2715     0     0    1      0        3        3
# 383         384  PEDX8413  2716  2715  2712    2      2        0        0
# 384         385  PEDX8437  3087     0     0    2      0        1        1
# 385         386  PEDX8437  3088     0     0    1      0        1        3
# 386         387  PEDX8437  3220  3088  3087    2      2        3        1
#
#      loc2.a1  ...  loc99.a1  loc99.a2  loc100.a1  loc100.a2  loc101.a1  \
# ...
