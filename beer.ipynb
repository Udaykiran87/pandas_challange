# %%
import pandas as pd

# %%
url2 = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt'

# %%
df = pd.read_csv(url2,sep="\t")

# %%
df.columns
# Out:
# Index(['name calories sodium alcohol cost'], dtype='object')

# %%
temp_ser = df['name calories sodium alcohol cost']

# %%
temp_list = []
for i in temp_ser:
    temp_list.append(i.split())

# %%
temp_list
# Out:
# [['Budweiser', '144', '15', '4.7', '0.43'],
#  ['Schlitz', '151', '19', '4.9', '0.43'],
#  ['Lowenbrau', '157', '15', '0.9', '0.48'],
#  ['Kronenbourg', '170', '7', '5.2', '0.73'],
#  ['Heineken', '152', '11', '5.0', '0.77'],
#  ['Old_Milwaukee', '145', '23', '4.6', '0.28'],
#  ['Augsberger', '175', '24', '5.5', '0.40'],
#  ['Srohs_Bohemian_Style', '149', '27', '4.7', '0.42'],
#  ['Miller_Lite', '99', '10', '4.3', '0.43'],
#  ['Budweiser_Light', '113', '8', '3.7', '0.40'],
#  ['Coors', '140', '18', '4.6', '0.44'],
#  ['Coors_Light', '102', '15', '4.1', '0.46'],
#  ['Michelob_Light', '135', '11', '4.2', '0.50'],
#  ['Becks', '150', '19', '4.7', '0.76'],
#  ['Kirin', '149', '6', '5.0', '0.79'],
#  ['Pabst_Extra_Light', '68', '15', '2.3', '0.38'],
#  ['Hamms', '139', '19', '4.4', '0.43'],
#  ['Heilemans_Old_Style', '144', '24', '4.9', '0.43'],
#  ['Olympia_Goled_Light', '72', '6', '2.9', '0.46'],
#  ['Schlitz_Light', '97', '7', '4.2', '0.47']]

# %%
df1 = pd.DataFrame(temp_list)

# %%
df1
# Out:
#                        0    1   2    3     4
# 0              Budweiser  144  15  4.7  0.43
# 1                Schlitz  151  19  4.9  0.43
# 2              Lowenbrau  157  15  0.9  0.48
# 3            Kronenbourg  170   7  5.2  0.73
# 4               Heineken  152  11  5.0  0.77
# 5          Old_Milwaukee  145  23  4.6  0.28
# 6             Augsberger  175  24  5.5  0.40
# 7   Srohs_Bohemian_Style  149  27  4.7  0.42
# 8            Miller_Lite   99  10  4.3  0.43
# 9        Budweiser_Light  113   8  3.7  0.40
# 10                 Coors  140  18  4.6  0.44
# 11           Coors_Light  102  15  4.1  0.46
# 12        Michelob_Light  135  11  4.2  0.50
# 13                 Becks  150  19  4.7  0.76
# 14                 Kirin  149   6  5.0  0.79
# 15     Pabst_Extra_Light   68  15  2.3  0.38
# 16                 Hamms  139  19  4.4  0.43
# 17   Heilemans_Old_Style  144  24  4.9  0.43
# 18   Olympia_Goled_Light   72   6  2.9  0.46
# 19         Schlitz_Light   97   7  4.2  0.47

# %%
headers = df.columns

# %%
headers = list(headers)

# %%
headers = headers[0].split()

# %%
headers
# Out:
# ['name', 'calories', 'sodium', 'alcohol', 'cost']

# %%
df1.columns = headers

# %%
df1
# Out:
#                     name calories sodium alcohol  cost
# 0              Budweiser      144     15     4.7  0.43
# 1                Schlitz      151     19     4.9  0.43
# 2              Lowenbrau      157     15     0.9  0.48
# 3            Kronenbourg      170      7     5.2  0.73
# 4               Heineken      152     11     5.0  0.77
# 5          Old_Milwaukee      145     23     4.6  0.28
# 6             Augsberger      175     24     5.5  0.40
# 7   Srohs_Bohemian_Style      149     27     4.7  0.42
# 8            Miller_Lite       99     10     4.3  0.43
# 9        Budweiser_Light      113      8     3.7  0.40
# 10                 Coors      140     18     4.6  0.44
# 11           Coors_Light      102     15     4.1  0.46
# 12        Michelob_Light      135     11     4.2  0.50
# 13                 Becks      150     19     4.7  0.76
# 14                 Kirin      149      6     5.0  0.79
# 15     Pabst_Extra_Light       68     15     2.3  0.38
# ...

# %%
df1.describe()
# Out:
#               name calories sodium alcohol  cost
# count           20       20     20      20    20
# unique          20       18     11      14    14
# top     Augsberger      144     15     4.7  0.43
# freq             1        2      4       3     5

# %%
df1.dtypes
# Out:
# name        object
# calories    object
# sodium      object
# alcohol     object
# cost        object
# dtype: object

# %%
df1['calories']
# Out:
# 0     144
# 1     151
# 2     157
# 3     170
# 4     152
# 5     145
# 6     175
# 7     149
# 8      99
# 9     113
# 10    140
# 11    102
# 12    135
# 13    150
# 14    149
# 15     68
# 16    139
# 17    144
# 18     72
# 19     97
# Name: calories, dtype: object

# %%
df1['calories_int'] = df1['calories'].astype(int)

# %%
df1
# Out:
#                     name calories sodium alcohol  cost  calories_int
# 0              Budweiser      144     15     4.7  0.43           144
# 1                Schlitz      151     19     4.9  0.43           151
# 2              Lowenbrau      157     15     0.9  0.48           157
# 3            Kronenbourg      170      7     5.2  0.73           170
# 4               Heineken      152     11     5.0  0.77           152
# 5          Old_Milwaukee      145     23     4.6  0.28           145
# 6             Augsberger      175     24     5.5  0.40           175
# 7   Srohs_Bohemian_Style      149     27     4.7  0.42           149
# 8            Miller_Lite       99     10     4.3  0.43            99
# 9        Budweiser_Light      113      8     3.7  0.40           113
# 10                 Coors      140     18     4.6  0.44           140
# 11           Coors_Light      102     15     4.1  0.46           102
# 12        Michelob_Light      135     11     4.2  0.50           135
# ...

# %%
df1[df1['calories_int']>150]
# Out:
#           name calories sodium alcohol  cost  calories_int
# 1      Schlitz      151     19     4.9  0.43           151
# 2    Lowenbrau      157     15     0.9  0.48           157
# 3  Kronenbourg      170      7     5.2  0.73           170
# 4     Heineken      152     11     5.0  0.77           152
# 6   Augsberger      175     24     5.5  0.40           175

# %%
df1['sodium_int'] = df1['sodium'].astype(int)
df1['alcohol_float'] = df1['alcohol'].astype(float)
df1['cost_float'] = df1['cost'].astype(float)

# %%
df1
# Out:
#                     name calories sodium alcohol  cost  calories_int  \
# 0              Budweiser      144     15     4.7  0.43           144
# 1                Schlitz      151     19     4.9  0.43           151
# 2              Lowenbrau      157     15     0.9  0.48           157
# 3            Kronenbourg      170      7     5.2  0.73           170
# 4               Heineken      152     11     5.0  0.77           152
# 5          Old_Milwaukee      145     23     4.6  0.28           145
# 6             Augsberger      175     24     5.5  0.40           175
# 7   Srohs_Bohemian_Style      149     27     4.7  0.42           149
# 8            Miller_Lite       99     10     4.3  0.43            99
# 9        Budweiser_Light      113      8     3.7  0.40           113
# 10                 Coors      140     18     4.6  0.44           140
# 11           Coors_Light      102     15     4.1  0.46           102
# 12        Michelob_Light      135     11     4.2  0.50           135
# ...

# %%
df1['cost_float'].argmax()
# Out:
# 14

# %%
df1.iloc[df1['cost_float'].argmax()]
# Out:
# name             Kirin
# calories           149
# sodium               6
# alcohol            5.0
# cost              0.79
# calories_int       149
# sodium_int           6
# alcohol_float        5
# cost_float        0.79
# Name: 14, dtype: object

# %%
df1['alcohol_float'].argmax()
# Out:
# 6

# %%
df1.iloc[df1['alcohol_float'].argmax()]
# Out:
# name             Augsberger
# calories                175
# sodium                   24
# alcohol                 5.5
# cost                   0.40
# calories_int            175
# sodium_int               24
# alcohol_float           5.5
# cost_float              0.4
# Name: 6, dtype: object

# %%
df1['sodium_int'].argmin()
# Out:
# 14

# %%
df1['calories_int'].argmin()
# Out:
# 15

# %%
df1.sort_values("calories_int")
# Out:
#                     name calories sodium alcohol  cost  calories_int  \
# 15     Pabst_Extra_Light       68     15     2.3  0.38            68
# 18   Olympia_Goled_Light       72      6     2.9  0.46            72
# 19         Schlitz_Light       97      7     4.2  0.47            97
# 8            Miller_Lite       99     10     4.3  0.43            99
# 11           Coors_Light      102     15     4.1  0.46           102
# 9        Budweiser_Light      113      8     3.7  0.40           113
# 12        Michelob_Light      135     11     4.2  0.50           135
# 16                 Hamms      139     19     4.4  0.43           139
# 10                 Coors      140     18     4.6  0.44           140
# 17   Heilemans_Old_Style      144     24     4.9  0.43           144
# 0              Budweiser      144     15     4.7  0.43           144
# 5          Old_Milwaukee      145     23     4.6  0.28           145
# 7   Srohs_Bohemian_Style      149     27     4.7  0.42           149
# ...
